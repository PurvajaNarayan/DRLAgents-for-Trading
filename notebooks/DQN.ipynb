# %% [markdown]
# # Reinforcement Learning based Trading Strategy
#
# In this case study, we will create an end-to-end trading strategy based on Reinforcement Learning.

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Loading the python packages

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv, set_option
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import datetime
import math
from numpy.random import choice
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from features.ohlcv_tech_indicators import OHLCVWithIndicators


#Import Model Packages for reinforcement learning
from keras import layers, models, optimizers
from keras import backend as K
from collections import namedtuple, deque

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Loading the Data

# %%
# Auto-detect all tickers from the data/processed folder
import os
import glob

data_dir = 'data/processed'
train_files = glob.glob(os.path.join(data_dir, '*_train.csv'))

# Extract unique ticker symbols
tickers = sorted(list(set([os.path.basename(f).replace('_train.csv', '') for f in train_files])))
tickers = ['AMZN']
print(f"Found {len(tickers)} tickers: {tickers}")

# Function to load data for a specific ticker
def load_ticker_data(ticker):
    """Load train, val, and test data for a given ticker."""
    train_set = read_csv(f'{data_dir}/{ticker}_train.csv', header=0)
    val_set = read_csv(f'{data_dir}/{ticker}_val.csv', header=0)
    test_set = read_csv(f'{data_dir}/{ticker}_test.csv', header=0)
    return train_set, val_set, test_set

# Display available data
for ticker in tickers:
    train, val, test = load_ticker_data(ticker)
    print(f"{ticker}: Train={train.shape}, Val={val.shape}, Test={test.shape}")
# Out:
# Found 1 tickers: ['AMZN']
# AMZN: Train=(1935, 6), Val=(415, 6), Test=(415, 6)

# %% [markdown]
# <a id='5.2'></a>
# ## 5.2. Implementation steps and modules

# %% [markdown]
# <a id='5.3'></a>
# ## 5.3. Agent script

# %%
import keras
from keras import layers
from keras.models import Sequential, load_model, clone_model
from keras.layers import Dense
from keras.optimizers import Adam
from collections import deque
import random
import numpy as np


class Agent:
    def __init__(self, state_size, initial_capital=10000, is_eval=False, model_name=""):
        self.state_size = state_size
        self.action_size = 3  # hold, buy, sell

        # Experience Replay Buffer
        self.memory = deque(maxlen=50000)

        self.model_name = model_name
        self.is_eval = is_eval

        # Portfolio tracking
        self.initial_capital = initial_capital
        self.cash = initial_capital
        self.shares_held = 0

        # DQN Hyperparameters
        self.gamma = 0.99            # Discount factor (Rainbow standard)
        self.epsilon = 0.3       # Start fully exploratory
        self.epsilon_min = 0.01      # Keep 1% exploration
        self.epsilon_decay = 0.995   # Per-episode decay

        # Minimum experiences before training starts
        self.train_start = 500

        # Target network update frequency (in training steps)
        self.target_update_freq = 500
        self.train_step_count = 0

        # Build networks
        if is_eval:
            self.model = load_model(model_name)
            self.target_model = clone_model(self.model)
            self.target_model.set_weights(self.model.get_weights())
        else:
            self.model = self._model()
            self.target_model = clone_model(self.model)
            self.target_model.set_weights(self.model.get_weights())

    def reset_portfolio(self):
        """Reset portfolio to initial state for new episode."""
        self.cash = self.initial_capital
        self.shares_held = 0

    def get_portfolio_value(self, current_price):
        """Calculate total portfolio value at current price."""
        return self.cash + (self.shares_held * current_price)

    def _model(self):
        model = Sequential()
        model.add(Dense(units=128, input_dim=self.state_size, activation="relu"))
        model.add(Dense(units=64, activation="relu"))
        model.add(Dense(units=32, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.compile(loss="mse", optimizer=Adam(learning_rate=0.0005))
        return model

    def update_target_network(self):
        """Copy online network weights to target network."""
        self.target_model.set_weights(self.model.get_weights())

    def act(self, state):
        """Epsilon-greedy action selection."""
        if not self.is_eval and random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        options = self.model.predict(state, verbose=0)
        return np.argmax(options[0])

    def remember(self, state, action, reward, next_state, done):
        """Store experience in replay buffer."""
        self.memory.append((state, action, reward, next_state, done))

    def expReplay(self, batch_size):
        """
        Experience Replay with Target Network.
        
        Uses the target network for TD target computation (Double DQN idea)
        to stabilize training. The target network is updated every
        target_update_freq training steps.
        """
        if len(self.memory) < self.train_start:
            return

        mini_batch = random.sample(self.memory, min(len(self.memory), batch_size))

        # Vectorize batch
        states = np.vstack([exp[0] for exp in mini_batch])
        actions = np.array([exp[1] for exp in mini_batch])
        rewards = np.array([exp[2] for exp in mini_batch])
        next_states = np.vstack([exp[3] for exp in mini_batch])
        dones = np.array([exp[4] for exp in mini_batch])

        # Online network: current Q-values and action selection for next states
        current_qs = self.model.predict(states, verbose=0)
        next_qs_online = self.model.predict(next_states, verbose=0)

        # Target network: Q-value evaluation for next states
        next_qs_target = self.target_model.predict(next_states, verbose=0)

        # Compute TD targets using Double DQN:
        # action selected by online net, evaluated by target net
        targets = current_qs.copy()
        for i in range(len(mini_batch)):
            if dones[i]:
                targets[i][actions[i]] = rewards[i]
            else:
                best_action = np.argmax(next_qs_online[i])
                targets[i][actions[i]] = rewards[i] + self.gamma * next_qs_target[i][best_action]

        # Single batch training step
        self.model.fit(states, targets, batch_size=batch_size, epochs=1, verbose=0)

        # Update target network periodically
        self.train_step_count += 1
        if self.train_step_count % self.target_update_freq == 0:
            self.update_target_network()

    def decay_epsilon(self):
        """Decay epsilon once per episode (not per replay call)."""
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# <a id='5.4'></a>
# ## 5.4. Helper Functions

# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
from features.ohlcv_tech_indicators import OHLCVWithIndicators


def formatPrice(n):
    """Format a number as a dollar amount."""
    return ("-$" if n < 0 else "$") + "{0:.2f}".format(abs(n))


def sigmoid(x):
    """Sigmoid function (kept for backwards compatibility)."""
    return 1 / (1 + math.exp(-x))


def getState(df, t, window_size, feature_builder, position):
    """
    Build observation using OHLCVWithIndicators.

    Args:
        df: DataFrame with OHLCV + precomputed indicators
        t: Current timestep (must be >= window_size)
        window_size: Size of the lookback window
        feature_builder: OHLCVWithIndicators instance
        position: 1.0 if holding shares, 0.0 if flat

    Returns:
        State vector of shape (1, state_dim) for model input
    """
    return feature_builder.build(df, t, position).reshape(1, -1)


def plot_behavior(data_input, states_buy, states_sell, profit):
    """Plot buy/sell signals on price chart."""
    fig = plt.figure(figsize=(15, 5))
    plt.plot(data_input, color='blue', lw=2.)
    plt.plot(data_input, '^', markersize=10, color='Green',
             label='Buying signal', markevery=states_buy)
    plt.plot(data_input, 'v', markersize=10, color='Red',
             label='Selling signal', markevery=states_sell)
    plt.title('Total gains: %f' % (profit))
    plt.legend()
    plt.show()

# %% [markdown]
# <a id='5.5'></a>
# ## 5.5. Training the data

# %%
# =============================================================================
# Configuration
# =============================================================================


window_size = 20
initial_capital = 10000
batch_size = 64
update_frequency = 4
transaction_cost = 0.001  # 0.1% per trade

# Episode design
episode_length = 180    # ~150 trading days per episode
episode_stride = 30       # 30-day stride between episode starts
num_passes = 3            # Number of full passes over the data

# =============================================================================
# Training Function for a Single Ticker
# =============================================================================
def train_ticker(ticker, train_set, window_size, initial_capital, batch_size, 
                 update_frequency, transaction_cost, episode_length, episode_stride, 
                 num_passes, verbose=True):
    """
    Train a DQN agent on a single ticker's data.
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL')
        train_set: Training DataFrame
        window_size: Lookback window for state
        initial_capital: Starting capital
        batch_size: Batch size for experience replay
        update_frequency: Steps between training updates
        transaction_cost: Cost per trade (fraction)
        episode_length: Length of each training episode
        episode_stride: Stride between episode starts
        num_passes: Number of full passes over data
        verbose: Whether to print detailed progress
        
    Returns:
        agent: Trained Agent object
        training_history: Dictionary with training metrics
    """
    # Initialize Feature Builder and Precompute Indicators
    feature_builder = OHLCVWithIndicators(window_size=window_size)
    state_size = feature_builder.obs_dim

    print(f"\n{'#'*70}")
    print(f"# TRAINING: {ticker}")
    print(f"{'#'*70}")
    print(f"State dimension: {state_size}")
    print(f"Transaction cost: {transaction_cost * 100}%")

    # Prepare Training Data
    train_df = train_set.copy()
    train_df = feature_builder.precompute(train_df)
    data = train_df['Close'].tolist()
    l = len(data)

    print(f"Data length: {l} trading days")
    print(f"Training starts from index {window_size}")

    # Generate Episode Start Indices (sliding window with stride)
    episode_starts = []
    start = window_size
    while start + episode_length < l:
        episode_starts.append(start)
        start += episode_stride

    print(f"Episodes per pass: {len(episode_starts)}")
    print(f"Total episodes: {len(episode_starts) * num_passes}")

    # Initialize Agent
    agent = Agent(state_size, initial_capital=initial_capital)
    
    # Training history for plotting
    training_history = {
        'episode_returns': [],
        'episode_values': [],
        'epsilon_history': [],
        'trade_counts': []
    }

    # Training Loop
    global_episode = 0

    for pass_num in range(num_passes):
        # Shuffle episode order each pass for diversity
        shuffled_starts = episode_starts.copy()
        random.shuffle(shuffled_starts)

        for ep_idx, start_idx in enumerate(shuffled_starts):
            global_episode += 1
            end_idx = min(start_idx + episode_length, l - 1)

            if verbose:
                print(f"\n{'='*60}")
                print(f"Pass {pass_num+1}/{num_passes} | Episode {ep_idx+1}/{len(episode_starts)} "
                      f"(Global #{global_episode}) | Epsilon: {agent.epsilon:.3f}")
                print(f"Window: day {start_idx} -> {end_idx} ({end_idx - start_idx} steps)")
                print(f"{'='*60}")

            # Reset portfolio for new episode
            agent.reset_portfolio()
            position = 0.0
            t = start_idx
            state = getState(train_df, t, window_size, feature_builder, position)

            # Track episode stats
            states_buy = []
            states_sell = []
            step_count = 0

            # Store initial portfolio value for terminal bonus
            initial_price = data[t]
            V_initial = agent.get_portfolio_value(initial_price)

            while t < end_idx:
                # Get portfolio value BEFORE action
                V_prev = agent.get_portfolio_value(data[t])

                action = agent.act(state)
                current_price = data[t]

                # EXECUTE ACTION
                if action == 1:  # BUY
                    if agent.cash > 0 and agent.shares_held == 0:
                        trade_value = agent.cash
                        cost = trade_value * transaction_cost
                        net_cash = agent.cash - cost
                        agent.shares_held = net_cash / current_price
                        agent.cash = 0
                        position = 1.0
                        states_buy.append(t)

                elif action == 2:  # SELL
                    if agent.shares_held > 0:
                        gross_sell_value = agent.shares_held * current_price
                        cost = gross_sell_value * transaction_cost
                        agent.cash = gross_sell_value - cost
                        agent.shares_held = 0
                        position = 0.0
                        states_sell.append(t)

                # REWARD
                next_price = data[t + 1] if (t + 1) < l else data[t]
                V_curr = agent.get_portfolio_value(next_price)

                if V_prev > 0 and V_curr > 0:
                    reward = V_curr - V_prev
                else:
                    reward = 0.0

                # TERMINAL BONUS
                done = (t >= end_idx - 1)
                if done:
                    V_final = agent.get_portfolio_value(data[min(t + 1, l - 1)])
                    if V_initial > 0 and V_final > 0:
                        terminal_bonus = V_final - V_initial
                        reward += terminal_bonus

                # Build next state
                next_t = min(t + 1, l - 1)
                next_state = getState(train_df, next_t, window_size, feature_builder, position)

                # Store and learn
                agent.remember(state, action, reward, next_state, done)
                state = next_state
                step_count += 1

                if step_count % update_frequency == 0:
                    agent.expReplay(batch_size)

                t += 1

            # Episode complete — decay epsilon
            agent.decay_epsilon()

            # Record history
            final_value = agent.get_portfolio_value(data[min(end_idx, l - 1)])
            total_return = final_value - initial_capital
            return_pct = (total_return / initial_capital) * 100
            
            training_history['episode_returns'].append(return_pct)
            training_history['episode_values'].append(final_value)
            training_history['epsilon_history'].append(agent.epsilon)
            training_history['trade_counts'].append(len(states_buy) + len(states_sell))

            if verbose:
                print(f"Final Value: {formatPrice(final_value)} | Return: {return_pct:.2f}%")
                print(f"Trades: {len(states_buy)} buys, {len(states_sell)} sells")
                print(f"Memory: {len(agent.memory)} | Train steps: {agent.train_step_count}")

        # Save model at end of each pass with ticker name
        os.makedirs("models", exist_ok=True)
        model_path = f"models/{ticker}_pass{pass_num}.keras"
        agent.model.save(model_path)
        print(f"\nModel saved: {model_path}")

    # Save final model
    final_model_path = f"models/{ticker}_final.keras"
    agent.model.save(final_model_path)
    print(f"\nFinal model saved: {final_model_path}")
    
    print(f"\nTraining complete for {ticker}. Final epsilon: {agent.epsilon:.4f}")
    print(f"Total episodes: {global_episode}")
    print(f"Total training steps: {agent.train_step_count}")
    
    return agent, training_history, feature_builder


def plot_training_history(ticker, history):
    """Plot training metrics for a ticker."""
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    fig.suptitle(f'Training History: {ticker}', fontsize=14, fontweight='bold')
    
    # Episode Returns
    ax1 = axes[0, 0]
    ax1.plot(history['episode_returns'], alpha=0.7)
    ax1.axhline(y=0, color='r', linestyle='--', alpha=0.5)
    # Moving average
    window = min(20, len(history['episode_returns']))
    if window > 1:
        ma = pd.Series(history['episode_returns']).rolling(window=window).mean()
        ax1.plot(ma, color='red', linewidth=2, label=f'{window}-ep MA')
    ax1.set_xlabel('Episode')
    ax1.set_ylabel('Return (%)')
    ax1.set_title('Episode Returns')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Portfolio Values
    ax2 = axes[0, 1]
    ax2.plot(history['episode_values'], alpha=0.7, color='green')
    ax2.axhline(y=initial_capital, color='r', linestyle='--', alpha=0.5, label='Initial Capital')
    ax2.set_xlabel('Episode')
    ax2.set_ylabel('Portfolio Value ($)')
    ax2.set_title('Episode Final Portfolio Values')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    # Epsilon Decay
    ax3 = axes[1, 0]
    ax3.plot(history['epsilon_history'], color='orange')
    ax3.set_xlabel('Episode')
    ax3.set_ylabel('Epsilon')
    ax3.set_title('Exploration Rate (Epsilon) Decay')
    ax3.grid(True, alpha=0.3)
    
    # Trade Counts
    ax4 = axes[1, 1]
    ax4.plot(history['trade_counts'], alpha=0.7, color='purple')
    if window > 1:
        ma = pd.Series(history['trade_counts']).rolling(window=window).mean()
        ax4.plot(ma, color='red', linewidth=2, label=f'{window}-ep MA')
    ax4.set_xlabel('Episode')
    ax4.set_ylabel('Total Trades')
    ax4.set_title('Trades per Episode')
    ax4.legend()
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'models/{ticker}_training_history.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    return fig

# %%
# =============================================================================
# MAIN TRAINING PIPELINE - TRAIN ALL TICKERS
# =============================================================================
# Dictionary to store trained agents and their results
trained_agents = {}
training_histories = {}
all_results = []

print("=" * 70)
print("MULTI-TICKER DQN TRAINING PIPELINE")
print("=" * 70)
print(f"\nTickers to train: {tickers}")
print(f"Configuration:")
print(f"  - Window size: {window_size}")
print(f"  - Initial capital: ${initial_capital}")
print(f"  - Episode length: {episode_length}")
print(f"  - Number of passes: {num_passes}")
print(f"  - Transaction cost: {transaction_cost*100}%")
print()

for ticker_idx, ticker in enumerate(tickers):
    print(f"\n{'*'*70}")
    print(f"* TICKER {ticker_idx + 1}/{len(tickers)}: {ticker}")
    print(f"{'*'*70}")
    
    # Load data for this ticker
    train_set, val_set, test_set = load_ticker_data(ticker)
    
    # Train the model
    agent, history, feature_builder = train_ticker(
        ticker=ticker,
        train_set=train_set,
        window_size=window_size,
        initial_capital=initial_capital,
        batch_size=batch_size,
        update_frequency=update_frequency,
        transaction_cost=transaction_cost,
        episode_length=episode_length,
        episode_stride=episode_stride,
        num_passes=num_passes,
        verbose=True  # Set to False for less output
    )
    
    # Store agent and history
    trained_agents[ticker] = agent
    training_histories[ticker] = history
    
    # Plot training history
    plot_training_history(ticker, history)
    
    # Print model summary (only for first ticker)
    if ticker_idx == 0:
        print("\nModel Architecture:")
        print(agent.model.summary())

print("\n" + "=" * 70)
print("TRAINING COMPLETE FOR ALL TICKERS")
print("=" * 70)
print("\nTrained models saved:")
for ticker in tickers:
    print(f"  - models/{ticker}_final.keras")
# Out:
# ======================================================================
# MULTI-TICKER DQN TRAINING PIPELINE
# ======================================================================
#
# Tickers to train: ['AMZN']
# Configuration:
#   - Window size: 20
#   - Initial capital: $10000
#   - Episode length: 180
#   - Number of passes: 3
#   - Transaction cost: 0.1%
#
#
# **********************************************************************
# * TICKER 1/1: AMZN
# **********************************************************************
#
# ######################################################################
# # TRAINING: AMZN
# ######################################################################
# State dimension: 107
# Transaction cost: 0.1%
# Data length: 1935 trading days
# Training starts from index 20
# Episodes per pass: 58
# Total episodes: 174
#
# ============================================================
# Pass 1/3 | Episode 1/58 (Global #1) | Epsilon: 0.300
# Window: day 1490 -> 1670 (180 steps)
# ============================================================
# /Users/prashanthjaganathan/Desktop/CS5180 - RL/DRLAgents-for-Trading/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Final Value: $9794.40 | Return: -2.06%
# Trades: 22 buys, 21 sells
# Memory: 180 | Train steps: 0
#
# ============================================================
# Pass 1/3 | Episode 2/58 (Global #2) | Epsilon: 0.298
# Window: day 1220 -> 1400 (180 steps)
# ============================================================
# Final Value: $15712.57 | Return: 57.13%
# Trades: 20 buys, 19 sells
# Memory: 360 | Train steps: 0
#
# ============================================================
# Pass 1/3 | Episode 3/58 (Global #3) | Epsilon: 0.297
# Window: day 80 -> 260 (180 steps)
# ============================================================
# Final Value: $11298.58 | Return: 12.99%
# Trades: 16 buys, 16 sells
# Memory: 540 | Train steps: 11
#
# ============================================================
# Pass 1/3 | Episode 4/58 (Global #4) | Epsilon: 0.296
# Window: day 980 -> 1160 (180 steps)
# ============================================================
# Final Value: $11448.77 | Return: 14.49%
# Trades: 9 buys, 8 sells
# Memory: 720 | Train steps: 56
#
# ============================================================
# Pass 1/3 | Episode 5/58 (Global #5) | Epsilon: 0.294
# Window: day 230 -> 410 (180 steps)
# ============================================================
# Final Value: $9749.56 | Return: -2.50%
# Trades: 9 buys, 8 sells
# Memory: 900 | Train steps: 101
#
# ============================================================
# Pass 1/3 | Episode 6/58 (Global #6) | Epsilon: 0.293
# Window: day 20 -> 200 (180 steps)
# ============================================================
# Final Value: $11344.81 | Return: 13.45%
# Trades: 10 buys, 10 sells
# Memory: 1080 | Train steps: 146
#
# ============================================================
# Pass 1/3 | Episode 7/58 (Global #7) | Epsilon: 0.291
# Window: day 1580 -> 1760 (180 steps)
# ============================================================
# Final Value: $10130.19 | Return: 1.30%
# Trades: 10 buys, 9 sells
# Memory: 1260 | Train steps: 191
#
# ============================================================
# Pass 1/3 | Episode 8/58 (Global #8) | Epsilon: 0.290
# Window: day 200 -> 380 (180 steps)
# ============================================================
# Final Value: $12220.01 | Return: 22.20%
# Trades: 5 buys, 5 sells
# Memory: 1440 | Train steps: 236
#
# ============================================================
# Pass 1/3 | Episode 9/58 (Global #9) | Epsilon: 0.288
# Window: day 1040 -> 1220 (180 steps)
# ============================================================
# Final Value: $11628.21 | Return: 16.28%
# Trades: 11 buys, 11 sells
# Memory: 1620 | Train steps: 281
#
# ============================================================
# Pass 1/3 | Episode 10/58 (Global #10) | Epsilon: 0.287
# Window: day 950 -> 1130 (180 steps)
# ============================================================
# Final Value: $10737.96 | Return: 7.38%
# Trades: 10 buys, 10 sells
# Memory: 1800 | Train steps: 326
#
# ============================================================
# Pass 1/3 | Episode 11/58 (Global #11) | Epsilon: 0.285
# Window: day 1640 -> 1820 (180 steps)
# ============================================================
# Final Value: $10644.01 | Return: 6.44%
# Trades: 10 buys, 9 sells
# Memory: 1980 | Train steps: 371
#
# ============================================================
# Pass 1/3 | Episode 12/58 (Global #12) | Epsilon: 0.284
# Window: day 350 -> 530 (180 steps)
# ============================================================
# Final Value: $10732.57 | Return: 7.33%
# Trades: 10 buys, 10 sells
# Memory: 2160 | Train steps: 416
#
# ============================================================
# Pass 1/3 | Episode 13/58 (Global #13) | Epsilon: 0.282
# Window: day 860 -> 1040 (180 steps)
# ============================================================
# Final Value: $8783.73 | Return: -12.16%
# Trades: 9 buys, 8 sells
# Memory: 2340 | Train steps: 461
#
# ============================================================
# Pass 1/3 | Episode 14/58 (Global #14) | Epsilon: 0.281
# Window: day 290 -> 470 (180 steps)
# ============================================================
# Final Value: $11805.27 | Return: 18.05%
# Trades: 12 buys, 12 sells
# Memory: 2520 | Train steps: 506
#
# ============================================================
# Pass 1/3 | Episode 15/58 (Global #15) | Epsilon: 0.280
# Window: day 680 -> 860 (180 steps)
# ============================================================
# Final Value: $13063.10 | Return: 30.63%
# Trades: 5 buys, 5 sells
# Memory: 2700 | Train steps: 551
#
# ============================================================
# Pass 1/3 | Episode 16/58 (Global #16) | Epsilon: 0.278
# Window: day 1010 -> 1190 (180 steps)
# ============================================================
# Final Value: $10411.34 | Return: 4.11%
# Trades: 11 buys, 10 sells
# Memory: 2880 | Train steps: 596
#
# ============================================================
# Pass 1/3 | Episode 17/58 (Global #17) | Epsilon: 0.277
# Window: day 1730 -> 1910 (180 steps)
# ============================================================
# Final Value: $9053.11 | Return: -9.47%
# Trades: 12 buys, 11 sells
# Memory: 3060 | Train steps: 641
#
# ============================================================
# Pass 1/3 | Episode 18/58 (Global #18) | Epsilon: 0.275
# Window: day 500 -> 680 (180 steps)
# ============================================================
# Final Value: $11348.85 | Return: 13.49%
# Trades: 9 buys, 8 sells
# Memory: 3240 | Train steps: 686
#
# ============================================================
# Pass 1/3 | Episode 19/58 (Global #19) | Epsilon: 0.274
# Window: day 650 -> 830 (180 steps)
# ============================================================
# Final Value: $10962.72 | Return: 9.63%
# Trades: 11 buys, 10 sells
# Memory: 3420 | Train steps: 731
#
# ============================================================
# Pass 1/3 | Episode 20/58 (Global #20) | Epsilon: 0.273
# Window: day 590 -> 770 (180 steps)
# ============================================================
# Final Value: $11924.30 | Return: 19.24%
# Trades: 13 buys, 12 sells
# Memory: 3600 | Train steps: 776
#
# ============================================================
# Pass 1/3 | Episode 21/58 (Global #21) | Epsilon: 0.271
# Window: day 1670 -> 1850 (180 steps)
# ============================================================
# Final Value: $8600.65 | Return: -13.99%
# Trades: 9 buys, 9 sells
# Memory: 3780 | Train steps: 821
#
# ============================================================
# Pass 1/3 | Episode 22/58 (Global #22) | Epsilon: 0.270
# Window: day 560 -> 740 (180 steps)
# ============================================================
# Final Value: $10069.74 | Return: 0.70%
# Trades: 16 buys, 15 sells
# Memory: 3960 | Train steps: 866
#
# ============================================================
# Pass 1/3 | Episode 23/58 (Global #23) | Epsilon: 0.269
# Window: day 530 -> 710 (180 steps)
# ============================================================
# Final Value: $10237.61 | Return: 2.38%
# Trades: 9 buys, 8 sells
# Memory: 4140 | Train steps: 911
#
# ============================================================
# Pass 1/3 | Episode 24/58 (Global #24) | Epsilon: 0.267
# Window: day 1310 -> 1490 (180 steps)
# ============================================================
# Final Value: $11377.57 | Return: 13.78%
# Trades: 10 buys, 10 sells
# Memory: 4320 | Train steps: 956
#
# ============================================================
# Pass 1/3 | Episode 25/58 (Global #25) | Epsilon: 0.266
# Window: day 1130 -> 1310 (180 steps)
# ============================================================
# Final Value: $10130.56 | Return: 1.31%
# Trades: 13 buys, 12 sells
# Memory: 4500 | Train steps: 1001
#
# ============================================================
# Pass 1/3 | Episode 26/58 (Global #26) | Epsilon: 0.265
# Window: day 1460 -> 1640 (180 steps)
# ============================================================
# Final Value: $9033.67 | Return: -9.66%
# Trades: 12 buys, 11 sells
# Memory: 4680 | Train steps: 1046
#
# ============================================================
# Pass 1/3 | Episode 27/58 (Global #27) | Epsilon: 0.263
# Window: day 140 -> 320 (180 steps)
# ============================================================
# Final Value: $9823.04 | Return: -1.77%
# Trades: 10 buys, 10 sells
# Memory: 4860 | Train steps: 1091
#
# ============================================================
# Pass 1/3 | Episode 28/58 (Global #28) | Epsilon: 0.262
# Window: day 1370 -> 1550 (180 steps)
# ============================================================
# Final Value: $12355.87 | Return: 23.56%
# Trades: 9 buys, 9 sells
# Memory: 5040 | Train steps: 1136
#
# ============================================================
# Pass 1/3 | Episode 29/58 (Global #29) | Epsilon: 0.261
# Window: day 1610 -> 1790 (180 steps)
# ============================================================
# Final Value: $10023.16 | Return: 0.23%
# Trades: 12 buys, 11 sells
# Memory: 5220 | Train steps: 1181
#
# ============================================================
# Pass 1/3 | Episode 30/58 (Global #30) | Epsilon: 0.259
# Window: day 710 -> 890 (180 steps)
# ============================================================
# Final Value: $14342.75 | Return: 43.43%
# Trades: 10 buys, 9 sells
# Memory: 5400 | Train steps: 1226
#
# ============================================================
# Pass 1/3 | Episode 31/58 (Global #31) | Epsilon: 0.258
# Window: day 260 -> 440 (180 steps)
# ============================================================
# Final Value: $10350.13 | Return: 3.50%
# Trades: 15 buys, 15 sells
# Memory: 5580 | Train steps: 1271
#
# ============================================================
# Pass 1/3 | Episode 32/58 (Global #32) | Epsilon: 0.257
# Window: day 1700 -> 1880 (180 steps)
# ============================================================
# Final Value: $6726.89 | Return: -32.73%
# Trades: 11 buys, 10 sells
# Memory: 5760 | Train steps: 1316
#
# ============================================================
# Pass 1/3 | Episode 33/58 (Global #33) | Epsilon: 0.256
# Window: day 380 -> 560 (180 steps)
# ============================================================
# Final Value: $11657.23 | Return: 16.57%
# Trades: 12 buys, 12 sells
# Memory: 5940 | Train steps: 1361
#
# ============================================================
# Pass 1/3 | Episode 34/58 (Global #34) | Epsilon: 0.254
# Window: day 1520 -> 1700 (180 steps)
# ============================================================
# Final Value: $10827.22 | Return: 8.27%
# Trades: 14 buys, 14 sells
# Memory: 6120 | Train steps: 1406
#
# ============================================================
# Pass 1/3 | Episode 35/58 (Global #35) | Epsilon: 0.253
# Window: day 740 -> 920 (180 steps)
# ============================================================
# Final Value: $16491.88 | Return: 64.92%
# Trades: 8 buys, 7 sells
# Memory: 6300 | Train steps: 1451
#
# ============================================================
# Pass 1/3 | Episode 36/58 (Global #36) | Epsilon: 0.252
# Window: day 1070 -> 1250 (180 steps)
# ============================================================
# Final Value: $9767.57 | Return: -2.32%
# Trades: 12 buys, 11 sells
# Memory: 6480 | Train steps: 1496
#
# ============================================================
# Pass 1/3 | Episode 37/58 (Global #37) | Epsilon: 0.250
# Window: day 1340 -> 1520 (180 steps)
# ============================================================
# Final Value: $10711.19 | Return: 7.11%
# Trades: 13 buys, 13 sells
# Memory: 6660 | Train steps: 1541
#
# ============================================================
# Pass 1/3 | Episode 38/58 (Global #38) | Epsilon: 0.249
# Window: day 770 -> 950 (180 steps)
# ============================================================
# Final Value: $12105.17 | Return: 21.05%
# Trades: 14 buys, 14 sells
# Memory: 6840 | Train steps: 1586
#
# ============================================================
# Pass 1/3 | Episode 39/58 (Global #39) | Epsilon: 0.248
# Window: day 1190 -> 1370 (180 steps)
# ============================================================
# Final Value: $10223.28 | Return: 2.23%
# Trades: 9 buys, 8 sells
# Memory: 7020 | Train steps: 1631
#
# ============================================================
# Pass 1/3 | Episode 40/58 (Global #40) | Epsilon: 0.247
# Window: day 1400 -> 1580 (180 steps)
# ============================================================
# Final Value: $8580.67 | Return: -14.19%
# Trades: 16 buys, 15 sells
# Memory: 7200 | Train steps: 1676
#
# ============================================================
# Pass 1/3 | Episode 41/58 (Global #41) | Epsilon: 0.245
# Window: day 830 -> 1010 (180 steps)
# ============================================================
# Final Value: $10473.53 | Return: 4.74%
# Trades: 11 buys, 10 sells
# Memory: 7380 | Train steps: 1721
#
# ============================================================
# Pass 1/3 | Episode 42/58 (Global #42) | Epsilon: 0.244
# Window: day 1100 -> 1280 (180 steps)
# ============================================================
# Final Value: $9005.22 | Return: -9.95%
# Trades: 13 buys, 13 sells
# Memory: 7560 | Train steps: 1766
#
# ============================================================
# Pass 1/3 | Episode 43/58 (Global #43) | Epsilon: 0.243
# Window: day 50 -> 230 (180 steps)
# ============================================================
# Final Value: $15588.55 | Return: 55.89%
# Trades: 9 buys, 9 sells
# Memory: 7740 | Train steps: 1811
#
# ============================================================
# Pass 1/3 | Episode 44/58 (Global #44) | Epsilon: 0.242
# Window: day 440 -> 620 (180 steps)
# ============================================================
# Final Value: $12401.10 | Return: 24.01%
# Trades: 12 buys, 12 sells
# Memory: 7920 | Train steps: 1856
#
# ============================================================
# Pass 1/3 | Episode 45/58 (Global #45) | Epsilon: 0.241
# Window: day 890 -> 1070 (180 steps)
# ============================================================
# Final Value: $10966.15 | Return: 9.66%
# Trades: 11 buys, 10 sells
# Memory: 8100 | Train steps: 1901
#
# ============================================================
# Pass 1/3 | Episode 46/58 (Global #46) | Epsilon: 0.239
# Window: day 920 -> 1100 (180 steps)
# ============================================================
# Final Value: $6867.56 | Return: -31.32%
# Trades: 15 buys, 15 sells
# Memory: 8280 | Train steps: 1946
#
# ============================================================
# Pass 1/3 | Episode 47/58 (Global #47) | Epsilon: 0.238
# Window: day 1280 -> 1460 (180 steps)
# ============================================================
# Final Value: $13832.38 | Return: 38.32%
# Trades: 14 buys, 13 sells
# Memory: 8460 | Train steps: 1991
#
# ============================================================
# Pass 1/3 | Episode 48/58 (Global #48) | Epsilon: 0.237
# Window: day 1250 -> 1430 (180 steps)
# ============================================================
# Final Value: $10750.52 | Return: 7.51%
# Trades: 12 buys, 11 sells
# Memory: 8640 | Train steps: 2036
#
# ============================================================
# Pass 1/3 | Episode 49/58 (Global #49) | Epsilon: 0.236
# Window: day 470 -> 650 (180 steps)
# ============================================================
# Final Value: $13111.31 | Return: 31.11%
# Trades: 11 buys, 10 sells
# Memory: 8820 | Train steps: 2081
#
# ============================================================
# Pass 1/3 | Episode 50/58 (Global #50) | Epsilon: 0.235
# Window: day 620 -> 800 (180 steps)
# ============================================================
# Final Value: $14552.67 | Return: 45.53%
# Trades: 13 buys, 12 sells
# Memory: 9000 | Train steps: 2126
#
# ============================================================
# Pass 1/3 | Episode 51/58 (Global #51) | Epsilon: 0.233
# Window: day 1430 -> 1610 (180 steps)
# ============================================================
# Final Value: $8148.42 | Return: -18.52%
# Trades: 15 buys, 15 sells
# Memory: 9180 | Train steps: 2171
#
# ============================================================
# Pass 1/3 | Episode 52/58 (Global #52) | Epsilon: 0.232
# Window: day 110 -> 290 (180 steps)
# ============================================================
# Final Value: $9133.20 | Return: -8.67%
# Trades: 12 buys, 11 sells
# Memory: 9360 | Train steps: 2216
#
# ============================================================
# Pass 1/3 | Episode 53/58 (Global #53) | Epsilon: 0.231
# Window: day 800 -> 980 (180 steps)
# ============================================================
# Final Value: $8280.61 | Return: -17.19%
# Trades: 12 buys, 12 sells
# Memory: 9540 | Train steps: 2261
#
# ============================================================
# Pass 1/3 | Episode 54/58 (Global #54) | Epsilon: 0.230
# Window: day 1160 -> 1340 (180 steps)
# ============================================================
# Final Value: $13412.53 | Return: 34.13%
# Trades: 12 buys, 12 sells
# Memory: 9720 | Train steps: 2306
#
# ============================================================
# Pass 1/3 | Episode 55/58 (Global #55) | Epsilon: 0.229
# Window: day 1550 -> 1730 (180 steps)
# ============================================================
# Final Value: $10407.91 | Return: 4.08%
# Trades: 12 buys, 11 sells
# Memory: 9900 | Train steps: 2351
#
# ============================================================
# Pass 1/3 | Episode 56/58 (Global #56) | Epsilon: 0.228
# Window: day 320 -> 500 (180 steps)
# ============================================================
# Final Value: $12122.76 | Return: 21.23%
# Trades: 9 buys, 8 sells
# Memory: 10080 | Train steps: 2396
#
# ============================================================
# Pass 1/3 | Episode 57/58 (Global #57) | Epsilon: 0.227
# Window: day 410 -> 590 (180 steps)
# ============================================================
# Final Value: $11693.66 | Return: 16.94%
# Trades: 12 buys, 11 sells
# Memory: 10260 | Train steps: 2441
#
# ============================================================
# Pass 1/3 | Episode 58/58 (Global #58) | Epsilon: 0.225
# Window: day 170 -> 350 (180 steps)
# ============================================================
# Final Value: $13045.53 | Return: 30.46%
# Trades: 14 buys, 13 sells
# Memory: 10440 | Train steps: 2486
#
# Model saved: models/AMZN_pass0.keras
#
# ============================================================
# Pass 2/3 | Episode 1/58 (Global #59) | Epsilon: 0.224
# Window: day 830 -> 1010 (180 steps)
# ============================================================
# Final Value: $9703.90 | Return: -2.96%
# Trades: 10 buys, 9 sells
# Memory: 10620 | Train steps: 2531
#
# ============================================================
# Pass 2/3 | Episode 2/58 (Global #60) | Epsilon: 0.223
# Window: day 1460 -> 1640 (180 steps)
# ============================================================
# Final Value: $9814.69 | Return: -1.85%
# Trades: 15 buys, 14 sells
# Memory: 10800 | Train steps: 2576
#
# ============================================================
# Pass 2/3 | Episode 3/58 (Global #61) | Epsilon: 0.222
# Window: day 1580 -> 1760 (180 steps)
# ============================================================
# Final Value: $9225.82 | Return: -7.74%
# Trades: 12 buys, 12 sells
# Memory: 10980 | Train steps: 2621
#
# ============================================================
# Pass 2/3 | Episode 4/58 (Global #62) | Epsilon: 0.221
# Window: day 950 -> 1130 (180 steps)
# ============================================================
# Final Value: $12405.50 | Return: 24.05%
# Trades: 10 buys, 9 sells
# Memory: 11160 | Train steps: 2666
#
# ============================================================
# Pass 2/3 | Episode 5/58 (Global #63) | Epsilon: 0.220
# Window: day 260 -> 440 (180 steps)
# ============================================================
# Final Value: $11608.25 | Return: 16.08%
# Trades: 14 buys, 13 sells
# Memory: 11340 | Train steps: 2711
#
# ============================================================
# Pass 2/3 | Episode 6/58 (Global #64) | Epsilon: 0.219
# Window: day 410 -> 590 (180 steps)
# ============================================================
# Final Value: $12700.36 | Return: 27.00%
# Trades: 15 buys, 14 sells
# Memory: 11520 | Train steps: 2756
#
# ============================================================
# Pass 2/3 | Episode 7/58 (Global #65) | Epsilon: 0.218
# Window: day 1340 -> 1520 (180 steps)
# ============================================================
# Final Value: $12304.84 | Return: 23.05%
# Trades: 19 buys, 19 sells
# Memory: 11700 | Train steps: 2801
#
# ============================================================
# Pass 2/3 | Episode 8/58 (Global #66) | Epsilon: 0.217
# Window: day 590 -> 770 (180 steps)
# ============================================================
# Final Value: $11695.60 | Return: 16.96%
# Trades: 18 buys, 17 sells
# Memory: 11880 | Train steps: 2846
#
# ============================================================
# Pass 2/3 | Episode 9/58 (Global #67) | Epsilon: 0.215
# Window: day 1100 -> 1280 (180 steps)
# ============================================================
# Final Value: $10741.43 | Return: 7.41%
# Trades: 12 buys, 12 sells
# Memory: 12060 | Train steps: 2891
#
# ============================================================
# Pass 2/3 | Episode 10/58 (Global #68) | Epsilon: 0.214
# Window: day 1430 -> 1610 (180 steps)
# ============================================================
# Final Value: $9062.70 | Return: -9.37%
# Trades: 13 buys, 13 sells
# Memory: 12240 | Train steps: 2936
#
# ============================================================
# Pass 2/3 | Episode 11/58 (Global #69) | Epsilon: 0.213
# Window: day 890 -> 1070 (180 steps)
# ============================================================
# Final Value: $8224.08 | Return: -17.76%
# Trades: 10 buys, 9 sells
# Memory: 12420 | Train steps: 2981
#
# ============================================================
# Pass 2/3 | Episode 12/58 (Global #70) | Epsilon: 0.212
# Window: day 710 -> 890 (180 steps)
# ============================================================
# Final Value: $15012.70 | Return: 50.13%
# Trades: 14 buys, 13 sells
# Memory: 12600 | Train steps: 3026
#
# ============================================================
# Pass 2/3 | Episode 13/58 (Global #71) | Epsilon: 0.211
# Window: day 1130 -> 1310 (180 steps)
# ============================================================
# Final Value: $9503.51 | Return: -4.96%
# Trades: 11 buys, 10 sells
# Memory: 12780 | Train steps: 3071
#
# ============================================================
# Pass 2/3 | Episode 14/58 (Global #72) | Epsilon: 0.210
# Window: day 680 -> 860 (180 steps)
# ============================================================
# Final Value: $13365.64 | Return: 33.66%
# Trades: 8 buys, 7 sells
# Memory: 12960 | Train steps: 3116
#
# ============================================================
# Pass 2/3 | Episode 15/58 (Global #73) | Epsilon: 0.209
# Window: day 1640 -> 1820 (180 steps)
# ============================================================
# Final Value: $10837.12 | Return: 8.37%
# Trades: 9 buys, 8 sells
# Memory: 13140 | Train steps: 3161
#
# ============================================================
# Pass 2/3 | Episode 16/58 (Global #74) | Epsilon: 0.208
# Window: day 1010 -> 1190 (180 steps)
# ============================================================
# Final Value: $11601.17 | Return: 16.01%
# Trades: 14 buys, 13 sells
# Memory: 13320 | Train steps: 3206
#
# ============================================================
# Pass 2/3 | Episode 17/58 (Global #75) | Epsilon: 0.207
# Window: day 500 -> 680 (180 steps)
# ============================================================
# Final Value: $12272.83 | Return: 22.73%
# Trades: 10 buys, 9 sells
# Memory: 13500 | Train steps: 3251
#
# ============================================================
# Pass 2/3 | Episode 18/58 (Global #76) | Epsilon: 0.206
# Window: day 80 -> 260 (180 steps)
# ============================================================
# Final Value: $13352.93 | Return: 33.53%
# Trades: 15 buys, 15 sells
# Memory: 13680 | Train steps: 3296
#
# ============================================================
# Pass 2/3 | Episode 19/58 (Global #77) | Epsilon: 0.205
# Window: day 440 -> 620 (180 steps)
# ============================================================
# Final Value: $11350.84 | Return: 13.51%
# Trades: 12 buys, 11 sells
# Memory: 13860 | Train steps: 3341
#
# ============================================================
# Pass 2/3 | Episode 20/58 (Global #78) | Epsilon: 0.204
# Window: day 1070 -> 1250 (180 steps)
# ============================================================
# Final Value: $9688.77 | Return: -3.11%
# Trades: 10 buys, 10 sells
# Memory: 14040 | Train steps: 3386
#
# ============================================================
# Pass 2/3 | Episode 21/58 (Global #79) | Epsilon: 0.203
# Window: day 1520 -> 1700 (180 steps)
# ============================================================
# Final Value: $9535.81 | Return: -4.64%
# Trades: 14 buys, 14 sells
# Memory: 14220 | Train steps: 3431
#
# ============================================================
# Pass 2/3 | Episode 22/58 (Global #80) | Epsilon: 0.202
# Window: day 1040 -> 1220 (180 steps)
# ============================================================
# Final Value: $10394.98 | Return: 3.95%
# Trades: 13 buys, 12 sells
# Memory: 14400 | Train steps: 3476
#
# ============================================================
# Pass 2/3 | Episode 23/58 (Global #81) | Epsilon: 0.201
# Window: day 50 -> 230 (180 steps)
# ============================================================
# Final Value: $15247.80 | Return: 52.48%
# Trades: 16 buys, 15 sells
# Memory: 14580 | Train steps: 3521
#
# ============================================================
# Pass 2/3 | Episode 24/58 (Global #82) | Epsilon: 0.200
# Window: day 470 -> 650 (180 steps)
# ============================================================
# Final Value: $12713.74 | Return: 27.14%
# Trades: 11 buys, 10 sells
# Memory: 14760 | Train steps: 3566
#
# ============================================================
# Pass 2/3 | Episode 25/58 (Global #83) | Epsilon: 0.199
# Window: day 320 -> 500 (180 steps)
# ============================================================
# Final Value: $10967.65 | Return: 9.68%
# Trades: 14 buys, 13 sells
# Memory: 14940 | Train steps: 3611
#
# ============================================================
# Pass 2/3 | Episode 26/58 (Global #84) | Epsilon: 0.198
# Window: day 620 -> 800 (180 steps)
# ============================================================
# Final Value: $15286.46 | Return: 52.86%
# Trades: 14 buys, 13 sells
# Memory: 15120 | Train steps: 3656
#
# ============================================================
# Pass 2/3 | Episode 27/58 (Global #85) | Epsilon: 0.197
# Window: day 770 -> 950 (180 steps)
# ============================================================
# Final Value: $11610.72 | Return: 16.11%
# Trades: 18 buys, 17 sells
# Memory: 15300 | Train steps: 3701
#
# ============================================================
# Pass 2/3 | Episode 28/58 (Global #86) | Epsilon: 0.196
# Window: day 860 -> 1040 (180 steps)
# ============================================================
# Final Value: $7404.20 | Return: -25.96%
# Trades: 15 buys, 15 sells
# Memory: 15480 | Train steps: 3746
#
# ============================================================
# Pass 2/3 | Episode 29/58 (Global #87) | Epsilon: 0.195
# Window: day 1310 -> 1490 (180 steps)
# ============================================================
# Final Value: $13416.48 | Return: 34.16%
# Trades: 13 buys, 12 sells
# Memory: 15660 | Train steps: 3791
#
# ============================================================
# Pass 2/3 | Episode 30/58 (Global #88) | Epsilon: 0.194
# Window: day 1160 -> 1340 (180 steps)
# ============================================================
# Final Value: $12381.03 | Return: 23.81%
# Trades: 12 buys, 11 sells
# Memory: 15840 | Train steps: 3836
#
# ============================================================
# Pass 2/3 | Episode 31/58 (Global #89) | Epsilon: 0.193
# Window: day 1250 -> 1430 (180 steps)
# ============================================================
# Final Value: $14597.79 | Return: 45.98%
# Trades: 11 buys, 10 sells
# Memory: 16020 | Train steps: 3881
#
# ============================================================
# Pass 2/3 | Episode 32/58 (Global #90) | Epsilon: 0.192
# Window: day 800 -> 980 (180 steps)
# ============================================================
# Final Value: $9554.58 | Return: -4.45%
# Trades: 11 buys, 10 sells
# Memory: 16200 | Train steps: 3926
#
# ============================================================
# Pass 2/3 | Episode 33/58 (Global #91) | Epsilon: 0.191
# Window: day 1370 -> 1550 (180 steps)
# ============================================================
# Final Value: $12128.23 | Return: 21.28%
# Trades: 16 buys, 15 sells
# Memory: 16380 | Train steps: 3971
#
# ============================================================
# Pass 2/3 | Episode 34/58 (Global #92) | Epsilon: 0.190
# Window: day 1190 -> 1370 (180 steps)
# ============================================================
# Final Value: $13468.18 | Return: 34.68%
# Trades: 17 buys, 16 sells
# Memory: 16560 | Train steps: 4016
#
# ============================================================
# Pass 2/3 | Episode 35/58 (Global #93) | Epsilon: 0.189
# Window: day 1400 -> 1580 (180 steps)
# ============================================================
# Final Value: $11229.91 | Return: 12.30%
# Trades: 14 buys, 13 sells
# Memory: 16740 | Train steps: 4061
#
# ============================================================
# Pass 2/3 | Episode 36/58 (Global #94) | Epsilon: 0.188
# Window: day 1700 -> 1880 (180 steps)
# ============================================================
# Final Value: $7234.95 | Return: -27.65%
# Trades: 13 buys, 13 sells
# Memory: 16920 | Train steps: 4106
#
# ============================================================
# Pass 2/3 | Episode 37/58 (Global #95) | Epsilon: 0.187
# Window: day 1280 -> 1460 (180 steps)
# ============================================================
# Final Value: $13110.72 | Return: 31.11%
# Trades: 18 buys, 17 sells
# Memory: 17100 | Train steps: 4151
#
# ============================================================
# Pass 2/3 | Episode 38/58 (Global #96) | Epsilon: 0.186
# Window: day 20 -> 200 (180 steps)
# ============================================================
# Final Value: $15509.15 | Return: 55.09%
# Trades: 10 buys, 9 sells
# Memory: 17280 | Train steps: 4196
#
# ============================================================
# Pass 2/3 | Episode 39/58 (Global #97) | Epsilon: 0.185
# Window: day 530 -> 710 (180 steps)
# ============================================================
# Final Value: $11909.79 | Return: 19.10%
# Trades: 18 buys, 17 sells
# Memory: 17460 | Train steps: 4241
#
# ============================================================
# Pass 2/3 | Episode 40/58 (Global #98) | Epsilon: 0.184
# Window: day 110 -> 290 (180 steps)
# ============================================================
# Final Value: $13324.94 | Return: 33.25%
# Trades: 13 buys, 12 sells
# Memory: 17640 | Train steps: 4286
#
# ============================================================
# Pass 2/3 | Episode 41/58 (Global #99) | Epsilon: 0.184
# Window: day 1670 -> 1850 (180 steps)
# ============================================================
# Final Value: $8559.53 | Return: -14.40%
# Trades: 16 buys, 15 sells
# Memory: 17820 | Train steps: 4331
#
# ============================================================
# Pass 2/3 | Episode 42/58 (Global #100) | Epsilon: 0.183
# Window: day 230 -> 410 (180 steps)
# ============================================================
# Final Value: $13035.98 | Return: 30.36%
# Trades: 15 buys, 15 sells
# Memory: 18000 | Train steps: 4376
#
# ============================================================
# Pass 2/3 | Episode 43/58 (Global #101) | Epsilon: 0.182
# Window: day 1220 -> 1400 (180 steps)
# ============================================================
# Final Value: $17340.45 | Return: 73.40%
# Trades: 20 buys, 19 sells
# Memory: 18180 | Train steps: 4421
#
# ============================================================
# Pass 2/3 | Episode 44/58 (Global #102) | Epsilon: 0.181
# Window: day 1730 -> 1910 (180 steps)
# ============================================================
# Final Value: $8822.94 | Return: -11.77%
# Trades: 15 buys, 14 sells
# Memory: 18360 | Train steps: 4466
#
# ============================================================
# Pass 2/3 | Episode 45/58 (Global #103) | Epsilon: 0.180
# Window: day 560 -> 740 (180 steps)
# ============================================================
# Final Value: $13570.45 | Return: 35.70%
# Trades: 16 buys, 15 sells
# Memory: 18540 | Train steps: 4511
#
# ============================================================
# Pass 2/3 | Episode 46/58 (Global #104) | Epsilon: 0.179
# Window: day 980 -> 1160 (180 steps)
# ============================================================
# Final Value: $13124.19 | Return: 31.24%
# Trades: 13 buys, 13 sells
# Memory: 18720 | Train steps: 4556
#
# ============================================================
# Pass 2/3 | Episode 47/58 (Global #105) | Epsilon: 0.178
# Window: day 1490 -> 1670 (180 steps)
# ============================================================
# Final Value: $11181.10 | Return: 11.81%
# Trades: 10 buys, 10 sells
# Memory: 18900 | Train steps: 4601
#
# ============================================================
# Pass 2/3 | Episode 48/58 (Global #106) | Epsilon: 0.177
# Window: day 380 -> 560 (180 steps)
# ============================================================
# Final Value: $10121.14 | Return: 1.21%
# Trades: 11 buys, 10 sells
# Memory: 19080 | Train steps: 4646
#
# ============================================================
# Pass 2/3 | Episode 49/58 (Global #107) | Epsilon: 0.176
# Window: day 1550 -> 1730 (180 steps)
# ============================================================
# Final Value: $10098.65 | Return: 0.99%
# Trades: 17 buys, 16 sells
# Memory: 19260 | Train steps: 4691
#
# ============================================================
# Pass 2/3 | Episode 50/58 (Global #108) | Epsilon: 0.175
# Window: day 1610 -> 1790 (180 steps)
# ============================================================
# Final Value: $9477.32 | Return: -5.23%
# Trades: 17 buys, 17 sells
# Memory: 19440 | Train steps: 4736
#
# ============================================================
# Pass 2/3 | Episode 51/58 (Global #109) | Epsilon: 0.175
# Window: day 170 -> 350 (180 steps)
# ============================================================
# Final Value: $14736.82 | Return: 47.37%
# Trades: 9 buys, 8 sells
# Memory: 19620 | Train steps: 4781
#
# ============================================================
# Pass 2/3 | Episode 52/58 (Global #110) | Epsilon: 0.174
# Window: day 200 -> 380 (180 steps)
# ============================================================
# Final Value: $12928.29 | Return: 29.28%
# Trades: 12 buys, 11 sells
# Memory: 19800 | Train steps: 4826
#
# ============================================================
# Pass 2/3 | Episode 53/58 (Global #111) | Epsilon: 0.173
# Window: day 290 -> 470 (180 steps)
# ============================================================
# Final Value: $13417.86 | Return: 34.18%
# Trades: 10 buys, 10 sells
# Memory: 19980 | Train steps: 4871
#
# ============================================================
# Pass 2/3 | Episode 54/58 (Global #112) | Epsilon: 0.172
# Window: day 740 -> 920 (180 steps)
# ============================================================
# Final Value: $15323.99 | Return: 53.24%
# Trades: 15 buys, 14 sells
# Memory: 20160 | Train steps: 4916
#
# ============================================================
# Pass 2/3 | Episode 55/58 (Global #113) | Epsilon: 0.171
# Window: day 650 -> 830 (180 steps)
# ============================================================
# Final Value: $13311.26 | Return: 33.11%
# Trades: 7 buys, 7 sells
# Memory: 20340 | Train steps: 4961
#
# ============================================================
# Pass 2/3 | Episode 56/58 (Global #114) | Epsilon: 0.170
# Window: day 350 -> 530 (180 steps)
# ============================================================
# Final Value: $11295.75 | Return: 12.96%
# Trades: 15 buys, 14 sells
# Memory: 20520 | Train steps: 5006
#
# ============================================================
# Pass 2/3 | Episode 57/58 (Global #115) | Epsilon: 0.169
# Window: day 920 -> 1100 (180 steps)
# ============================================================
# Final Value: $9318.95 | Return: -6.81%
# Trades: 12 buys, 12 sells
# Memory: 20700 | Train steps: 5051
#
# ============================================================
# Pass 2/3 | Episode 58/58 (Global #116) | Epsilon: 0.169
# Window: day 140 -> 320 (180 steps)
# ============================================================
# Final Value: $12434.64 | Return: 24.35%
# Trades: 11 buys, 10 sells
# Memory: 20880 | Train steps: 5096
#
# Model saved: models/AMZN_pass1.keras
#
# ============================================================
# Pass 3/3 | Episode 1/58 (Global #117) | Epsilon: 0.168
# Window: day 320 -> 500 (180 steps)
# ============================================================
# Final Value: $14064.19 | Return: 40.64%
# Trades: 10 buys, 9 sells
# Memory: 21060 | Train steps: 5141
#
# ============================================================
# Pass 3/3 | Episode 2/58 (Global #118) | Epsilon: 0.167
# Window: day 1730 -> 1910 (180 steps)
# ============================================================
# Final Value: $8614.33 | Return: -13.86%
# Trades: 12 buys, 11 sells
# Memory: 21240 | Train steps: 5186
#
# ============================================================
# Pass 3/3 | Episode 3/58 (Global #119) | Epsilon: 0.166
# Window: day 1070 -> 1250 (180 steps)
# ============================================================
# Final Value: $9215.64 | Return: -7.84%
# Trades: 11 buys, 11 sells
# Memory: 21420 | Train steps: 5231
#
# ============================================================
# Pass 3/3 | Episode 4/58 (Global #120) | Epsilon: 0.165
# Window: day 110 -> 290 (180 steps)
# ============================================================
# Final Value: $12912.35 | Return: 29.12%
# Trades: 11 buys, 11 sells
# Memory: 21600 | Train steps: 5276
#
# ============================================================
# Pass 3/3 | Episode 5/58 (Global #121) | Epsilon: 0.164
# Window: day 1610 -> 1790 (180 steps)
# ============================================================
# Final Value: $11945.58 | Return: 19.46%
# Trades: 13 buys, 13 sells
# Memory: 21780 | Train steps: 5321
#
# ============================================================
# Pass 3/3 | Episode 6/58 (Global #122) | Epsilon: 0.164
# Window: day 1130 -> 1310 (180 steps)
# ============================================================
# Final Value: $9977.29 | Return: -0.23%
# Trades: 12 buys, 11 sells
# Memory: 21960 | Train steps: 5366
#
# ============================================================
# Pass 3/3 | Episode 7/58 (Global #123) | Epsilon: 0.163
# Window: day 380 -> 560 (180 steps)
# ============================================================
# Final Value: $11928.47 | Return: 19.28%
# Trades: 9 buys, 8 sells
# Memory: 22140 | Train steps: 5411
#
# ============================================================
# Pass 3/3 | Episode 8/58 (Global #124) | Epsilon: 0.162
# Window: day 290 -> 470 (180 steps)
# ============================================================
# Final Value: $12997.54 | Return: 29.98%
# Trades: 10 buys, 10 sells
# Memory: 22320 | Train steps: 5456
#
# ============================================================
# Pass 3/3 | Episode 9/58 (Global #125) | Epsilon: 0.161
# Window: day 530 -> 710 (180 steps)
# ============================================================
# Final Value: $10898.33 | Return: 8.98%
# Trades: 12 buys, 11 sells
# Memory: 22500 | Train steps: 5501
#
# ============================================================
# Pass 3/3 | Episode 10/58 (Global #126) | Epsilon: 0.160
# Window: day 1430 -> 1610 (180 steps)
# ============================================================
# Final Value: $11375.92 | Return: 13.76%
# Trades: 17 buys, 16 sells
# Memory: 22680 | Train steps: 5546
#
# ============================================================
# Pass 3/3 | Episode 11/58 (Global #127) | Epsilon: 0.160
# Window: day 1220 -> 1400 (180 steps)
# ============================================================
# Final Value: $16499.52 | Return: 65.00%
# Trades: 10 buys, 9 sells
# Memory: 22860 | Train steps: 5591
#
# ============================================================
# Pass 3/3 | Episode 12/58 (Global #128) | Epsilon: 0.159
# Window: day 1580 -> 1760 (180 steps)
# ============================================================
# Final Value: $9953.79 | Return: -0.46%
# Trades: 17 buys, 16 sells
# Memory: 23040 | Train steps: 5636
#
# ============================================================
# Pass 3/3 | Episode 13/58 (Global #129) | Epsilon: 0.158
# Window: day 260 -> 440 (180 steps)
# ============================================================
# Final Value: $17674.12 | Return: 76.74%
# Trades: 15 buys, 14 sells
# Memory: 23220 | Train steps: 5681
#
# ============================================================
# Pass 3/3 | Episode 14/58 (Global #130) | Epsilon: 0.157
# Window: day 500 -> 680 (180 steps)
# ============================================================
# Final Value: $13208.44 | Return: 32.08%
# Trades: 11 buys, 10 sells
# Memory: 23400 | Train steps: 5726
#
# ============================================================
# Pass 3/3 | Episode 15/58 (Global #131) | Epsilon: 0.156
# Window: day 590 -> 770 (180 steps)
# ============================================================
# Final Value: $13404.33 | Return: 34.04%
# Trades: 17 buys, 16 sells
# Memory: 23580 | Train steps: 5771
#
# ============================================================
# Pass 3/3 | Episode 16/58 (Global #132) | Epsilon: 0.156
# Window: day 170 -> 350 (180 steps)
# ============================================================
# Final Value: $16010.62 | Return: 60.11%
# Trades: 14 buys, 13 sells
# Memory: 23760 | Train steps: 5816
#
# ============================================================
# Pass 3/3 | Episode 17/58 (Global #133) | Epsilon: 0.155
# Window: day 1160 -> 1340 (180 steps)
# ============================================================
# Final Value: $14693.06 | Return: 46.93%
# Trades: 21 buys, 20 sells
# Memory: 23940 | Train steps: 5861
#
# ============================================================
# Pass 3/3 | Episode 18/58 (Global #134) | Epsilon: 0.154
# Window: day 1490 -> 1670 (180 steps)
# ============================================================
# Final Value: $11816.29 | Return: 18.16%
# Trades: 18 buys, 18 sells
# Memory: 24120 | Train steps: 5906
#
# ============================================================
# Pass 3/3 | Episode 19/58 (Global #135) | Epsilon: 0.153
# Window: day 1460 -> 1640 (180 steps)
# ============================================================
# Final Value: $12928.44 | Return: 29.28%
# Trades: 22 buys, 21 sells
# Memory: 24300 | Train steps: 5951
#
# ============================================================
# Pass 3/3 | Episode 20/58 (Global #136) | Epsilon: 0.152
# Window: day 440 -> 620 (180 steps)
# ============================================================
# Final Value: $11171.42 | Return: 11.71%
# Trades: 13 buys, 12 sells
# Memory: 24480 | Train steps: 5996
#
# ============================================================
# Pass 3/3 | Episode 21/58 (Global #137) | Epsilon: 0.152
# Window: day 830 -> 1010 (180 steps)
# ============================================================
# Final Value: $11510.61 | Return: 15.11%
# Trades: 13 buys, 12 sells
# Memory: 24660 | Train steps: 6041
#
# ============================================================
# Pass 3/3 | Episode 22/58 (Global #138) | Epsilon: 0.151
# Window: day 980 -> 1160 (180 steps)
# ============================================================
# Final Value: $12159.57 | Return: 21.60%
# Trades: 18 buys, 17 sells
# Memory: 24840 | Train steps: 6086
#
# ============================================================
# Pass 3/3 | Episode 23/58 (Global #139) | Epsilon: 0.150
# Window: day 890 -> 1070 (180 steps)
# ============================================================
# Final Value: $10731.44 | Return: 7.31%
# Trades: 15 buys, 15 sells
# Memory: 25020 | Train steps: 6131
#
# ============================================================
# Pass 3/3 | Episode 24/58 (Global #140) | Epsilon: 0.149
# Window: day 230 -> 410 (180 steps)
# ============================================================
# Final Value: $12868.23 | Return: 28.68%
# Trades: 11 buys, 10 sells
# Memory: 25200 | Train steps: 6176
#
# ============================================================
# Pass 3/3 | Episode 25/58 (Global #141) | Epsilon: 0.149
# Window: day 140 -> 320 (180 steps)
# ============================================================
# Final Value: $12778.72 | Return: 27.79%
# Trades: 12 buys, 11 sells
# Memory: 25380 | Train steps: 6221
#
# ============================================================
# Pass 3/3 | Episode 26/58 (Global #142) | Epsilon: 0.148
# Window: day 1100 -> 1280 (180 steps)
# ============================================================
# Final Value: $11736.17 | Return: 17.36%
# Trades: 22 buys, 21 sells
# Memory: 25560 | Train steps: 6266
#
# ============================================================
# Pass 3/3 | Episode 27/58 (Global #143) | Epsilon: 0.147
# Window: day 620 -> 800 (180 steps)
# ============================================================
# Final Value: $14306.17 | Return: 43.06%
# Trades: 11 buys, 10 sells
# Memory: 25740 | Train steps: 6311
#
# ============================================================
# Pass 3/3 | Episode 28/58 (Global #144) | Epsilon: 0.146
# Window: day 470 -> 650 (180 steps)
# ============================================================
# Final Value: $11538.28 | Return: 15.38%
# Trades: 12 buys, 11 sells
# Memory: 25920 | Train steps: 6356
#
# ============================================================
# Pass 3/3 | Episode 29/58 (Global #145) | Epsilon: 0.146
# Window: day 1250 -> 1430 (180 steps)
# ============================================================
# Final Value: $16210.89 | Return: 62.11%
# Trades: 7 buys, 6 sells
# Memory: 26100 | Train steps: 6401
#
# ============================================================
# Pass 3/3 | Episode 30/58 (Global #146) | Epsilon: 0.145
# Window: day 1340 -> 1520 (180 steps)
# ============================================================
# Final Value: $14959.86 | Return: 49.60%
# Trades: 15 buys, 15 sells
# Memory: 26280 | Train steps: 6446
#
# ============================================================
# Pass 3/3 | Episode 31/58 (Global #147) | Epsilon: 0.144
# Window: day 1520 -> 1700 (180 steps)
# ============================================================
# Final Value: $11533.12 | Return: 15.33%
# Trades: 14 buys, 14 sells
# Memory: 26460 | Train steps: 6491
#
# ============================================================
# Pass 3/3 | Episode 32/58 (Global #148) | Epsilon: 0.144
# Window: day 1550 -> 1730 (180 steps)
# ============================================================
# Final Value: $12630.68 | Return: 26.31%
# Trades: 12 buys, 11 sells
# Memory: 26640 | Train steps: 6536
#
# ============================================================
# Pass 3/3 | Episode 33/58 (Global #149) | Epsilon: 0.143
# Window: day 920 -> 1100 (180 steps)
# ============================================================
# Final Value: $12842.85 | Return: 28.43%
# Trades: 19 buys, 19 sells
# Memory: 26820 | Train steps: 6581
#
# ============================================================
# Pass 3/3 | Episode 34/58 (Global #150) | Epsilon: 0.142
# Window: day 200 -> 380 (180 steps)
# ============================================================
# Final Value: $15398.53 | Return: 53.99%
# Trades: 10 buys, 9 sells
# Memory: 27000 | Train steps: 6626
#
# ============================================================
# Pass 3/3 | Episode 35/58 (Global #151) | Epsilon: 0.141
# Window: day 50 -> 230 (180 steps)
# ============================================================
# Final Value: $19063.40 | Return: 90.63%
# Trades: 12 buys, 11 sells
# Memory: 27180 | Train steps: 6671
#
# ============================================================
# Pass 3/3 | Episode 36/58 (Global #152) | Epsilon: 0.141
# Window: day 1010 -> 1190 (180 steps)
# ============================================================
# Final Value: $12111.32 | Return: 21.11%
# Trades: 17 buys, 16 sells
# Memory: 27360 | Train steps: 6716
#
# ============================================================
# Pass 3/3 | Episode 37/58 (Global #153) | Epsilon: 0.140
# Window: day 800 -> 980 (180 steps)
# ============================================================
# Final Value: $10755.19 | Return: 7.55%
# Trades: 12 buys, 11 sells
# Memory: 27540 | Train steps: 6761
#
# ============================================================
# Pass 3/3 | Episode 38/58 (Global #154) | Epsilon: 0.139
# Window: day 1640 -> 1820 (180 steps)
# ============================================================
# Final Value: $9378.19 | Return: -6.22%
# Trades: 19 buys, 18 sells
# Memory: 27720 | Train steps: 6806
#
# ============================================================
# Pass 3/3 | Episode 39/58 (Global #155) | Epsilon: 0.139
# Window: day 350 -> 530 (180 steps)
# ============================================================
# Final Value: $10661.18 | Return: 6.61%
# Trades: 17 buys, 16 sells
# Memory: 27900 | Train steps: 6851
#
# ============================================================
# Pass 3/3 | Episode 40/58 (Global #156) | Epsilon: 0.138
# Window: day 770 -> 950 (180 steps)
# ============================================================
# Final Value: $11457.45 | Return: 14.57%
# Trades: 12 buys, 11 sells
# Memory: 28080 | Train steps: 6896
#
# ============================================================
# Pass 3/3 | Episode 41/58 (Global #157) | Epsilon: 0.137
# Window: day 650 -> 830 (180 steps)
# ============================================================
# Final Value: $12439.01 | Return: 24.39%
# Trades: 9 buys, 9 sells
# Memory: 28260 | Train steps: 6941
#
# ============================================================
# Pass 3/3 | Episode 42/58 (Global #158) | Epsilon: 0.137
# Window: day 680 -> 860 (180 steps)
# ============================================================
# Final Value: $13847.97 | Return: 38.48%
# Trades: 10 buys, 9 sells
# Memory: 28440 | Train steps: 6986
#
# ============================================================
# Pass 3/3 | Episode 43/58 (Global #159) | Epsilon: 0.136
# Window: day 1040 -> 1220 (180 steps)
# ============================================================
# Final Value: $11250.13 | Return: 12.50%
# Trades: 15 buys, 14 sells
# Memory: 28620 | Train steps: 7031
#
# ============================================================
# Pass 3/3 | Episode 44/58 (Global #160) | Epsilon: 0.135
# Window: day 1190 -> 1370 (180 steps)
# ============================================================
# Final Value: $13386.19 | Return: 33.86%
# Trades: 15 buys, 14 sells
# Memory: 28800 | Train steps: 7076
#
# ============================================================
# Pass 3/3 | Episode 45/58 (Global #161) | Epsilon: 0.135
# Window: day 1670 -> 1850 (180 steps)
# ============================================================
# Final Value: $10217.42 | Return: 2.17%
# Trades: 17 buys, 17 sells
# Memory: 28980 | Train steps: 7121
#
# ============================================================
# Pass 3/3 | Episode 46/58 (Global #162) | Epsilon: 0.134
# Window: day 1370 -> 1550 (180 steps)
# ============================================================
# Final Value: $13242.09 | Return: 32.42%
# Trades: 15 buys, 15 sells
# Memory: 29160 | Train steps: 7166
#
# ============================================================
# Pass 3/3 | Episode 47/58 (Global #163) | Epsilon: 0.133
# Window: day 1700 -> 1880 (180 steps)
# ============================================================
# Final Value: $8810.51 | Return: -11.89%
# Trades: 14 buys, 14 sells
# Memory: 29340 | Train steps: 7211
#
# ============================================================
# Pass 3/3 | Episode 48/58 (Global #164) | Epsilon: 0.133
# Window: day 710 -> 890 (180 steps)
# ============================================================
# Final Value: $17470.15 | Return: 74.70%
# Trades: 10 buys, 9 sells
# Memory: 29520 | Train steps: 7256
#
# ============================================================
# Pass 3/3 | Episode 49/58 (Global #165) | Epsilon: 0.132
# Window: day 1400 -> 1580 (180 steps)
# ============================================================
# Final Value: $10618.12 | Return: 6.18%
# Trades: 21 buys, 20 sells
# Memory: 29700 | Train steps: 7301
#
# ============================================================
# Pass 3/3 | Episode 50/58 (Global #166) | Epsilon: 0.131
# Window: day 410 -> 590 (180 steps)
# ============================================================
# Final Value: $11141.04 | Return: 11.41%
# Trades: 14 buys, 13 sells
# Memory: 29880 | Train steps: 7346
#
# ============================================================
# Pass 3/3 | Episode 51/58 (Global #167) | Epsilon: 0.131
# Window: day 860 -> 1040 (180 steps)
# ============================================================
# Final Value: $12442.59 | Return: 24.43%
# Trades: 20 buys, 19 sells
# Memory: 30060 | Train steps: 7391
#
# ============================================================
# Pass 3/3 | Episode 52/58 (Global #168) | Epsilon: 0.130
# Window: day 20 -> 200 (180 steps)
# ============================================================
# Final Value: $15055.80 | Return: 50.56%
# Trades: 16 buys, 15 sells
# Memory: 30240 | Train steps: 7436
#
# ============================================================
# Pass 3/3 | Episode 53/58 (Global #169) | Epsilon: 0.129
# Window: day 80 -> 260 (180 steps)
# ============================================================
# Final Value: $13105.53 | Return: 31.06%
# Trades: 12 buys, 12 sells
# Memory: 30420 | Train steps: 7481
#
# ============================================================
# Pass 3/3 | Episode 54/58 (Global #170) | Epsilon: 0.129
# Window: day 560 -> 740 (180 steps)
# ============================================================
# Final Value: $12292.44 | Return: 22.92%
# Trades: 12 buys, 11 sells
# Memory: 30600 | Train steps: 7526
#
# ============================================================
# Pass 3/3 | Episode 55/58 (Global #171) | Epsilon: 0.128
# Window: day 950 -> 1130 (180 steps)
# ============================================================
# Final Value: $15874.68 | Return: 58.75%
# Trades: 12 buys, 11 sells
# Memory: 30780 | Train steps: 7571
#
# ============================================================
# Pass 3/3 | Episode 56/58 (Global #172) | Epsilon: 0.127
# Window: day 1310 -> 1490 (180 steps)
# ============================================================
# Final Value: $18103.82 | Return: 81.04%
# Trades: 11 buys, 10 sells
# Memory: 30960 | Train steps: 7616
#
# ============================================================
# Pass 3/3 | Episode 57/58 (Global #173) | Epsilon: 0.127
# Window: day 740 -> 920 (180 steps)
# ============================================================
# Final Value: $15539.67 | Return: 55.40%
# Trades: 12 buys, 11 sells
# Memory: 31140 | Train steps: 7661
#
# ============================================================
# Pass 3/3 | Episode 58/58 (Global #174) | Epsilon: 0.126
# Window: day 1280 -> 1460 (180 steps)
# ============================================================
# Final Value: $16878.42 | Return: 68.78%
# Trades: 18 buys, 17 sells
# Memory: 31320 | Train steps: 7706
#
# Model saved: models/AMZN_pass2.keras
#
# Final model saved: models/AMZN_final.keras
#
# Training complete for AMZN. Final epsilon: 0.1254
# Total episodes: 174
# Total training steps: 7706
# Model Architecture:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 128)            │        13,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 72,779 (284.30 KB)
#  Trainable params: 24,259 (94.76 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 48,520 (189.54 KB)
# None
#
# ======================================================================
# TRAINING COMPLETE FOR ALL TICKERS
# ======================================================================
#
# Trained models saved:
#   - models/AMZN_final.keras

# %% [markdown]
# <a id='6'></a>
# # 6. Testing the Data

# %% [markdown]
# After training the data, it is tested it against the test dataset. Our model resulted in a overall profit. The best thing about the model was that the profits kept improving over time, indicating that it was learning well and taking better actions.

# %%
# =============================================================================
# VALIDATION/TEST EVALUATION FUNCTION
# =============================================================================
def evaluate_ticker(ticker, agent, eval_set, feature_builder, window_size, 
                    initial_capital, transaction_cost, eval_type="VALIDATION"):
    """
    Evaluate a trained agent on validation or test data.
    
    Args:
        ticker: Stock ticker symbol
        agent: Trained Agent object
        eval_set: Evaluation DataFrame (val or test)
        feature_builder: OHLCVWithIndicators instance
        window_size: Lookback window
        initial_capital: Starting capital
        transaction_cost: Cost per trade (fraction)
        eval_type: "VALIDATION" or "TEST"
        
    Returns:
        results: Dictionary with evaluation metrics
    """
    print("=" * 70)
    print(f"{eval_type} SET EVALUATION: {ticker}")
    print("=" * 70)
 
    # Prepare data
    eval_df = eval_set.copy()
    eval_df = feature_builder.precompute(eval_df)
    eval_data = eval_df['Close'].tolist()
    eval_l = len(eval_data) - 1
 
    # Set agent to evaluation mode
    agent.is_eval = True
    agent.epsilon = 0.0
 
    # Reset portfolio
    agent.reset_portfolio()
 
    # Initialize tracking
    t = window_size
    position = 0.0
    state = getState(eval_df, t, window_size, feature_builder, position)
 
    states_buy = []
    states_sell = []
    trades = []
    total_transaction_costs = 0.0
    buy_entry_cost = 0.0
 
    print(f"\nStarting Capital: {formatPrice(initial_capital)}")
    print(f"{eval_type} Period: {eval_l - window_size} trading days")
    print("-" * 70)
    print(f"{'Action':<8} {'Time':<8} {'Price':<12} {'Shares':<12} {'Trade P/L':<12} {'TxnCost':<10} {'Portfolio':<12}")
    print("-" * 70)
 
    while t < eval_l:
        action = agent.act(state)
        current_price = eval_data[t]
        trade_info = None
 
        if action == 1:  # BUY
            if agent.cash > 0 and agent.shares_held == 0:
                trade_value = agent.cash
                cost = trade_value * transaction_cost
                net_cash = agent.cash - cost
                buy_entry_cost = agent.cash
                agent.shares_held = net_cash / current_price
                agent.cash = 0
                position = 1.0
                total_transaction_costs += cost
                states_buy.append(t)
 
                portfolio_value = agent.get_portfolio_value(current_price)
                trade_info = {
                    'action': 'BUY', 'time': t, 'price': current_price,
                    'shares': agent.shares_held, 'trade_pnl': -cost,
                    'txn_cost': cost, 'portfolio': portfolio_value
                }
                print(f"{'BUY':<8} {t:<8} {formatPrice(current_price):<12} "
                      f"{agent.shares_held:<12.4f} {formatPrice(-cost):<12} "
                      f"{formatPrice(cost):<10} {formatPrice(portfolio_value):<12}")
 
        elif action == 2:  # SELL
            if agent.shares_held > 0:
                gross_sell_value = agent.shares_held * current_price
                cost = gross_sell_value * transaction_cost
                net_sell_value = gross_sell_value - cost
                trade_pnl = net_sell_value - buy_entry_cost
                shares_sold = agent.shares_held
                agent.cash = net_sell_value
                agent.shares_held = 0
                position = 0.0
                total_transaction_costs += cost
                states_sell.append(t)
 
                portfolio_value = agent.get_portfolio_value(current_price)
                trade_info = {
                    'action': 'SELL', 'time': t, 'price': current_price,
                    'shares': shares_sold, 'trade_pnl': trade_pnl,
                    'txn_cost': cost, 'portfolio': portfolio_value
                }
                print(f"{'SELL':<8} {t:<8} {formatPrice(current_price):<12} "
                      f"{shares_sold:<12.4f} {formatPrice(trade_pnl):<12} "
                      f"{formatPrice(cost):<10} {formatPrice(portfolio_value):<12}")
 
        if trade_info:
            trades.append(trade_info)
 
        done = (t == eval_l - 1)
        next_state = getState(eval_df, t + 1, window_size, feature_builder, position) if not done else state
        state = next_state
        t += 1
 
    # LIQUIDATE if still holding
    final_price = eval_data[eval_l - 1]
    if agent.shares_held > 0:
        gross_sell_value = agent.shares_held * final_price
        liquidation_cost = gross_sell_value * transaction_cost
        net_liquidation = gross_sell_value - liquidation_cost
        trade_pnl = net_liquidation - buy_entry_cost
        total_transaction_costs += liquidation_cost
 
        print(f"\n--- LIQUIDATION at end of period ---")
        print(f"{'SELL':<8} {'END':<8} {formatPrice(final_price):<12} "
              f"{agent.shares_held:<12.4f} {formatPrice(trade_pnl):<12} "
              f"{formatPrice(liquidation_cost):<10} {formatPrice(net_liquidation):<12}")
 
        trades.append({
            'action': 'SELL', 'time': eval_l, 'price': final_price,
            'shares': agent.shares_held, 'trade_pnl': trade_pnl,
            'txn_cost': liquidation_cost, 'portfolio': net_liquidation
        })
        states_sell.append(eval_l)
        agent.cash = net_liquidation
        agent.shares_held = 0
 
    # Calculate results
    final_portfolio = agent.cash
    dqn_return = final_portfolio - initial_capital
    dqn_return_pct = (dqn_return / initial_capital) * 100
 
    # Buy and Hold Comparison
    start_price = eval_data[window_size]
    end_price = eval_data[eval_l - 1]
    bh_buy_cost = initial_capital * transaction_cost
    bh_shares = (initial_capital - bh_buy_cost) / start_price
    bh_gross_sell = bh_shares * end_price
    bh_sell_cost = bh_gross_sell * transaction_cost
    bh_final_value = bh_gross_sell - bh_sell_cost
    bh_return = bh_final_value - initial_capital
    bh_return_pct = (bh_return / initial_capital) * 100
    bh_total_costs = bh_buy_cost + bh_sell_cost
 
    # Trade Analysis
    sell_trades = [t for t in trades if t['action'] == 'SELL']
    winning_trades = [t for t in sell_trades if t['trade_pnl'] > 0]
    losing_trades = [t for t in sell_trades if t['trade_pnl'] <= 0]
    total_wins = sum(t['trade_pnl'] for t in winning_trades)
    total_losses = sum(t['trade_pnl'] for t in losing_trades)
 
    # Print Summary
    print("\n" + "=" * 70)
    print(f"{eval_type} SET RESULTS SUMMARY: {ticker}")
    print("=" * 70)
    print(f"\n{'DQN STRATEGY':^35} | {'BUY & HOLD':^35}")
    print("-" * 70)
    print(f"{'Initial Capital:':<20} {formatPrice(initial_capital):<15} | {'Initial Capital:':<20} {formatPrice(initial_capital):<15}")
    print(f"{'Final Portfolio:':<20} {formatPrice(final_portfolio):<15} | {'Final Value:':<20} {formatPrice(bh_final_value):<15}")
    print(f"{'Total Return:':<20} {formatPrice(dqn_return):<15} | {'Total Return:':<20} {formatPrice(bh_return):<15}")
    print(f"{'Return %:':<20} {dqn_return_pct:<14.2f}% | {'Return %:':<20} {bh_return_pct:<14.2f}%")
    print(f"\n{'Total Txn Costs:':<20} {formatPrice(total_transaction_costs):<15} | {'Total Txn Costs:':<20} {formatPrice(bh_total_costs):<15}")
    print(f"{'Total Trades:':<20} {len(trades):<15} | {'Total Trades:':<20} {'2':<15}")
    print(f"{'  - Buys:':<20} {len(states_buy):<15}")
    print(f"{'  - Sells:':<20} {len(states_sell):<15}")
 
    if len(sell_trades) > 0:
        print(f"\n{'TRADE STATISTICS':^70}")
        print("-" * 70)
        print(f"{'Winning Trades:':<25} {len(winning_trades)}")
        print(f"{'Losing Trades:':<25} {len(losing_trades)}")
        win_rate = len(winning_trades) / len(sell_trades) * 100
        print(f"{'Win Rate:':<25} {win_rate:.1f}%")
        print(f"{'Total Profit (wins):':<25} {formatPrice(total_wins)}")
        print(f"{'Total Loss (losses):':<25} {formatPrice(total_losses)}")
        if len(winning_trades) > 0:
            print(f"{'Avg Win:':<25} {formatPrice(total_wins / len(winning_trades))}")
        if len(losing_trades) > 0:
            print(f"{'Avg Loss:':<25} {formatPrice(total_losses / len(losing_trades))}")
 
    print(f"\n{'COST ANALYSIS':^70}")
    print("-" * 70)
    print(f"{'Total Txn Costs:':<25} {formatPrice(total_transaction_costs)}")
    print(f"{'Net Return:':<25} {formatPrice(dqn_return)}")
    print(f"{'Costs as % of Capital:':<25} {(total_transaction_costs/initial_capital)*100:.2f}%")
 
    print("\n" + "-" * 70)
    if dqn_return > bh_return:
        outperformance = dqn_return - bh_return
        print(f"DQN OUTPERFORMED Buy & Hold by {formatPrice(outperformance)} ({(outperformance/initial_capital)*100:.2f}%)")
    else:
        underperformance = bh_return - dqn_return
        print(f"DQN UNDERPERFORMED Buy & Hold by {formatPrice(underperformance)} ({(underperformance/initial_capital)*100:.2f}%)")
    print("=" * 70)
    
    # Plot
    plot_behavior(eval_data, states_buy, states_sell, dqn_return)
    
    # Return results dictionary
    results = {
        'ticker': ticker,
        'eval_type': eval_type,
        'final_portfolio': final_portfolio,
        'dqn_return': dqn_return,
        'dqn_return_pct': dqn_return_pct,
        'bh_return': bh_return,
        'bh_return_pct': bh_return_pct,
        'total_trades': len(trades),
        'num_buys': len(states_buy),
        'num_sells': len(states_sell),
        'total_transaction_costs': total_transaction_costs,
        'outperformance': dqn_return - bh_return,
        'win_rate': len(winning_trades) / len(sell_trades) * 100 if len(sell_trades) > 0 else 0
    }
    
    return results

# %%
# =============================================================================
# EVALUATE ALL TICKERS ON VALIDATION AND TEST SETS
# =============================================================================
validation_results = []
test_results = []

print("=" * 70)
print("EVALUATION PIPELINE - ALL TICKERS")
print("=" * 70)
print(tickers)
for ticker in tickers:
    print(f"\n{'*'*70}")
    print(f"* EVALUATING: {ticker}")
    print(f"{'*'*70}")
    
    # Load data for this ticker
    train_set, val_set, test_set = load_ticker_data(ticker)
    
    # Get the trained agent for this ticker
    agent = trained_agents[ticker]
    
    # Recreate feature builder (needed for evaluation)
    feature_builder = OHLCVWithIndicators(window_size=window_size)
    
    # Evaluate on validation set
    val_result = evaluate_ticker(
        ticker=ticker,
        agent=agent,
        eval_set=val_set,
        feature_builder=feature_builder,
        window_size=window_size,
        initial_capital=initial_capital,
        transaction_cost=transaction_cost,
        eval_type="VALIDATION"
    )
    validation_results.append(val_result)
    
    # Evaluate on test set
    test_result = evaluate_ticker(
        ticker=ticker,
        agent=agent,
        eval_set=test_set,
        feature_builder=feature_builder,
        window_size=window_size,
        initial_capital=initial_capital,
        transaction_cost=transaction_cost,
        eval_type="TEST"
    )
    test_results.append(test_result)

# =============================================================================
# SUMMARY TABLE FOR ALL TICKERS
# =============================================================================
print("\n" + "=" * 90)
print("FINAL SUMMARY - ALL TICKERS")
print("=" * 90)

# Validation Summary
print("\n" + "-" * 90)
print("VALIDATION SET RESULTS")
print("-" * 90)
print(f"{'Ticker':<8} {'DQN Return%':<12} {'B&H Return%':<12} {'Outperform%':<12} {'Win Rate%':<10} {'Trades':<8}")
print("-" * 90)
for r in validation_results:
    outperf = r['dqn_return_pct'] - r['bh_return_pct']
    print(f"{r['ticker']:<8} {r['dqn_return_pct']:<12.2f} {r['bh_return_pct']:<12.2f} {outperf:<12.2f} {r['win_rate']:<10.1f} {r['total_trades']:<8}")

# Test Summary
print("\n" + "-" * 90)
print("TEST SET RESULTS")
print("-" * 90)
print(f"{'Ticker':<8} {'DQN Return%':<12} {'B&H Return%':<12} {'Outperform%':<12} {'Win Rate%':<10} {'Trades':<8}")
print("-" * 90)
for r in test_results:
    outperf = r['dqn_return_pct'] - r['bh_return_pct']
    print(f"{r['ticker']:<8} {r['dqn_return_pct']:<12.2f} {r['bh_return_pct']:<12.2f} {outperf:<12.2f} {r['win_rate']:<10.1f} {r['total_trades']:<8}")

# Average performance
print("\n" + "-" * 90)
print("AVERAGE PERFORMANCE")
print("-" * 90)
avg_val_dqn = sum(r['dqn_return_pct'] for r in validation_results) / len(validation_results)
avg_val_bh = sum(r['bh_return_pct'] for r in validation_results) / len(validation_results)
avg_test_dqn = sum(r['dqn_return_pct'] for r in test_results) / len(test_results)
avg_test_bh = sum(r['bh_return_pct'] for r in test_results) / len(test_results)

print(f"Validation - DQN Avg: {avg_val_dqn:.2f}%, B&H Avg: {avg_val_bh:.2f}%, Outperformance: {avg_val_dqn - avg_val_bh:.2f}%")
print(f"Test       - DQN Avg: {avg_test_dqn:.2f}%, B&H Avg: {avg_test_bh:.2f}%, Outperformance: {avg_test_dqn - avg_test_bh:.2f}%")

print("\n" + "=" * 90)
print("EVALUATION COMPLETE")
print("=" * 90)
# Out:
# ======================================================================
# EVALUATION PIPELINE - ALL TICKERS
# ======================================================================
# ['CHWY']
#
# **********************************************************************
# * EVALUATING: CHWY
# **********************************************************************
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 20
#      16     # Load data for this ticker
#      17     train_set, val_set, test_set = load_ticker_data(ticker)
#      18
#      19     # Get the trained agent for this ticker
# ---> 20     agent = trained_agents[ticker]
#      21
#      22     # Recreate feature builder (needed for evaluation)
#      23     feature_builder = OHLCVWithIndicators(window_size=window_size)
#
# KeyError: 'CHWY'

# %%
# =============================================================================
# UTILITY: LOAD AND EVALUATE A SAVED MODEL
# =============================================================================
def load_and_evaluate_ticker(ticker, model_path=None, eval_type="both"):
    """
    Load a saved model and evaluate it on validation and/or test data.
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL')
        model_path: Path to saved model. If None, uses 'models/{ticker}_final.keras'
        eval_type: "validation", "test", or "both"
        
    Returns:
        results: Dictionary with evaluation results
    """
    if model_path is None:
        model_path = f"models/{ticker}_final.keras"
    
    print(f"\nLoading model from: {model_path}")
    
    # Create agent in evaluation mode with the saved model
    feature_builder = OHLCVWithIndicators(window_size=window_size)
    state_size = feature_builder.obs_dim
    agent = Agent(state_size, initial_capital=initial_capital, is_eval=True, model_name=model_path)
    
    # Load ticker data
    train_set, val_set, test_set = load_ticker_data(ticker)
    
    results = {}
    
    if eval_type in ["validation", "both"]:
        val_result = evaluate_ticker(
            ticker=ticker,
            agent=agent,
            eval_set=val_set,
            feature_builder=feature_builder,
            window_size=window_size,
            initial_capital=initial_capital,
            transaction_cost=transaction_cost,
            eval_type="VALIDATION"
        )
        results['validation'] = val_result
    
    if eval_type in ["test", "both"]:
        # Need to recreate agent/feature builder since evaluate_ticker modifies them
        feature_builder = OHLCVWithIndicators(window_size=window_size)
        agent = Agent(state_size, initial_capital=initial_capital, is_eval=True, model_name=model_path)
        
        test_result = evaluate_ticker(
            ticker=ticker,
            agent=agent,
            eval_set=test_set,
            feature_builder=feature_builder,
            window_size=window_size,
            initial_capital=initial_capital,
            transaction_cost=transaction_cost,
            eval_type="TEST"
        )
        results['test'] = test_result
    
    return results


# Example usage (uncomment to run):
results = load_and_evaluate_ticker('AMZN', eval_type='both')
# results = load_and_evaluate_ticker('AAPL', eval_type='test')
# results = load_and_evaluate_ticker('MSFT', eval_type='test')




# print("\n" + "=" * 70)
# print("UTILITY FUNCTION LOADED: load_and_evaluate_ticker()")
# print("=" * 70)
# print("""
# Usage examples:
#   # Evaluate AAPL with final model on both val and test
#   results = load_and_evaluate_ticker('AAPL')
  
#   # Evaluate MSFT with a specific pass model on test only
#   results = load_and_evaluate_ticker('MSFT', model_path='models/MSFT_pass1.keras', eval_type='test')
  
#   # Evaluate GOOGL on validation only
#   results = load_and_evaluate_ticker('GOOGL', eval_type='validation')
# """)
# Out:
# Loading model from: models/AMZN_final.keras
# ======================================================================
# VALIDATION SET EVALUATION: AMZN
# ======================================================================
#
# Starting Capital: $10000.00
# VALIDATION Period: 394 trading days
# ----------------------------------------------------------------------
# Action   Time     Price        Shares       Trade P/L    TxnCost    Portfolio
# ----------------------------------------------------------------------
# BUY      24       $112.53      88.7763      -$10.00      $10.00     $9990.00
# SELL     34       $110.96      88.7763      -$159.23     $9.85      $9840.77
# BUY      35       $103.41      95.0675      -$9.84       $9.84      $9830.93
# SELL     41       $90.53       95.0675      -$1242.92    $8.61      $8597.85
# BUY      55       $93.95       91.4237      -$8.60       $8.60      $8589.26
# SELL     65       $90.55       91.4237      -$327.72     $8.28      $8270.14
# BUY      66       $92.49       89.3271      -$8.27       $8.27      $8261.87
# SELL     75       $83.04       89.3271      -$859.83     $7.42      $7410.31
# BUY      87       $98.12       75.4474      -$7.41       $7.41      $7402.90
# SELL     112      $94.58       75.4474      -$281.63     $7.14      $7128.68
# BUY      120      $94.90       75.0427      -$7.13       $7.13      $7121.55
# SELL     126      $92.43       75.0427      -$199.42     $6.94      $6929.26
# BUY      130      $98.95       69.9578      -$6.93       $6.93      $6922.33
# SELL     157      $104.98      69.9578      $407.57      $7.34      $7336.83
# BUY      158      $109.82      66.7410      -$7.34       $7.34      $7329.49
# SELL     224      $128.21      66.7410      $1211.47     $8.56      $8548.30
# BUY      227      $142.22      60.0461      -$8.55       $8.55      $8539.76
# SELL     229      $137.85      60.0461      -$279.23     $8.28      $8269.08
# BUY      230      $138.56      59.6190      -$8.27       $8.27      $8260.81
# SELL     241      $133.26      59.6190      -$332.19     $7.94      $7936.88
# BUY      247      $137.27      57.7617      -$7.94       $7.94      $7928.95
# SELL     249      $137.85      57.7617      $17.60       $7.96      $7954.49
# BUY      250      $138.23      57.4877      -$7.95       $7.95      $7946.53
# SELL     262      $125.98      57.4877      -$719.42     $7.24      $7235.06
# BUY      275      $129.79      55.6886      -$7.24       $7.24      $7227.83
# SELL     282      $128.56      55.6886      -$82.89      $7.16      $7152.17
# BUY      283      $121.39      58.8600      -$7.15       $7.15      $7145.02
# SELL     333      $149.10      58.8600      $1615.08     $8.78      $8767.26
# BUY      340      $153.50      57.0586      -$8.77       $8.77      $8758.49
# SELL     407      $176.59      57.0586      $1298.64     $10.08     $10065.90
#
# ======================================================================
# VALIDATION SET RESULTS SUMMARY: AMZN
# ======================================================================
#
#            DQN STRATEGY             |             BUY & HOLD
# ----------------------------------------------------------------------
# Initial Capital:     $10000.00       | Initial Capital:     $10000.00
# Final Portfolio:     $10065.90       | Final Value:         $16092.07
# Total Return:        $65.90          | Total Return:        $6092.07
# Return %:            0.66          % | Return %:            60.92         %
#
# Total Txn Costs:     $242.94         | Total Txn Costs:     $26.11
# Total Trades:        30              | Total Trades:        2
#   - Buys:            15
#   - Sells:           15
#
#                            TRADE STATISTICS
# ----------------------------------------------------------------------
# Winning Trades:           5
# Losing Trades:            10
# Win Rate:                 33.3%
# Total Profit (wins):      $4550.37
# Total Loss (losses):      -$4484.48
# Avg Win:                  $910.07
# Avg Loss:                 -$448.45
#
#                             COST ANALYSIS
# ----------------------------------------------------------------------
# Total Txn Costs:          $242.94
# Net Return:               $65.90
# Costs as % of Capital:    2.43%
#
# ----------------------------------------------------------------------
# DQN UNDERPERFORMED Buy & Hold by $6026.17 (60.26%)
# ======================================================================
# ======================================================================
# TEST SET EVALUATION: AMZN
# ======================================================================
#
# Starting Capital: $10000.00
# TEST Period: 394 trading days
# ----------------------------------------------------------------------
# Action   Time     Price        Shares       Trade P/L    TxnCost    Portfolio
# ----------------------------------------------------------------------
# BUY      27       $183.83      54.3437      -$10.00      $10.00     $9990.00
# SELL     52       $182.55      54.3437      -$89.48      $9.92      $9910.52
# BUY      75       $176.13      56.2119      -$9.91       $9.91      $9900.61
# SELL     86       $175.40      56.2119      -$60.81      $9.86      $9849.71
# BUY      88       $184.52      53.3268      -$9.85       $9.85      $9839.86
# SELL     89       $187.00      53.3268      $112.43      $9.97      $9962.14
# BUY      90       $186.49      53.3658      -$9.96       $9.96      $9952.18
# SELL     107      $182.72      53.3658      -$220.90     $9.75      $9741.24
# BUY      115      $188.99      51.4921      -$9.74       $9.74      $9731.50
# SELL     116      $189.07      51.4921      -$15.36      $9.74      $9725.88
# BUY      117      $189.70      51.2185      -$9.73       $9.73      $9716.16
# SELL     142      $207.86      51.2185      $909.76      $10.65     $10635.64
# BUY      148      $220.55      48.1750      -$10.64      $10.64     $10625.00
# SELL     167      $224.19      48.1750      $153.92      $10.80     $10789.56
# BUY      177      $230.71      46.7200      -$10.79      $10.79     $10778.77
# SELL     186      $237.42      46.7200      $291.61      $11.09     $11081.17
# BUY      187      $242.06      45.7328      -$11.08      $11.08     $11070.09
# SELL     195      $228.68      45.7328      -$633.44     $10.46     $10447.73
# BUY      222      $201.13      51.8932      -$10.45      $10.45     $10437.28
# SELL     226      $192.17      51.8932      -$485.38     $9.97      $9962.34
# BUY      229      $171.00      58.2010      -$9.96       $9.96      $9952.38
# SELL     316      $221.30      58.2010      $2904.67     $12.88     $12867.01
# BUY      323      $223.81      57.4333      -$12.87      $12.87     $12854.15
# SELL     350      $222.17      57.4333      -$119.82     $12.76     $12747.19
# BUY      373      $222.86      57.1410      -$12.75      $12.75     $12734.45
# SELL     374      $244.22      57.1410      $1193.83     $13.95     $13941.02
# BUY      375      $254.00      54.8310      -$13.94      $13.94     $13927.08
# SELL     387      $222.69      54.8310      -$1742.91    $12.21     $12198.11
# BUY      403      $226.19      53.8747      -$12.20      $12.20     $12185.92
# SELL     406      $221.27      53.8747      -$289.18     $11.92     $11908.93
# BUY      413      $232.07      51.2648      -$11.91      $11.91     $11897.02
#
# --- LIQUIDATION at end of period ---
# SELL     END      $232.07      51.2648      -$23.81      $11.90     $11885.13
#
# ======================================================================
# TEST SET RESULTS SUMMARY: AMZN
# ======================================================================
#
#            DQN STRATEGY             |             BUY & HOLD
# ----------------------------------------------------------------------
# Initial Capital:     $10000.00       | Initial Capital:     $10000.00
# Final Portfolio:     $11885.13       | Final Value:         $12914.36
# Total Return:        $1885.13        | Total Return:        $2914.36
# Return %:            18.85         % | Return %:            29.14         %
#
# Total Txn Costs:     $353.60         | Total Txn Costs:     $22.93
# Total Trades:        32              | Total Trades:        2
#   - Buys:            16
#   - Sells:           16
#
#                            TRADE STATISTICS
# ----------------------------------------------------------------------
# Winning Trades:           6
# Losing Trades:            10
# Win Rate:                 37.5%
# Total Profit (wins):      $5566.22
# Total Loss (losses):      -$3681.09
# Avg Win:                  $927.70
# Avg Loss:                 -$368.11
#
#                             COST ANALYSIS
# ----------------------------------------------------------------------
# Total Txn Costs:          $353.60
# Net Return:               $1885.13
# Costs as % of Capital:    3.54%
#
# ----------------------------------------------------------------------
# DQN UNDERPERFORMED Buy & Hold by $1029.23 (10.29%)
# ======================================================================
